# %%
from joblib import dump,load
import numpy as np
model=load("SellingHouse.joblib")

# %%
features=np.array([[-0.40264632, -0.48985762, -0.20983103, -0.27180623, -0.12415942,
       -0.591457031,  0.91440729,  0.91895396, -0.66335337, -0.64115372,
       -0.03662739,  0.38834112,  0.7767358]])
model.predict(features)
# Out:
# array([17.618])
